# %% [markdown]
# # Zeckendorf representation
#
# ***Give the 0-1 list that indicates the unique nonconsecutive Fibonacci numbers that sum to the non-negative integer input***

# %% [markdown]
# ----
#
# ## Documentation

# %% [markdown]
# ### Usage

# %% [markdown]
# | `zeckendor-representation(n)` |
# |---|
# | Gives the 0-1 list that indicates the unique nonconsecutive Fibonacci numbers that sum to the non-negative integer $n$.|

# %% [markdown]
# ### Details & Options

# %% [markdown]
# - The Fibonacci numbers here are considered to be $1, 2, 3, 5, ...$, not $1, 1, 2, 3, 5, ...$; otherwise, the representation would not be unique.

# %% [markdown]
# ----
#
# ## Setup

# %%
use Math::NumberTheory;
use Math::Zeckendorf;

use Graph;
use Graph::Classes;

use JavaScript::D3;

# %%
#% javascript
require.config({
     paths: {
     d3: 'https://d3js.org/d3.v7.min'
}});

require(['d3'], function(d3) {
     console.log(d3);
});

# %%
#% js
js-d3-list-line-plot(10.rand xx 40, background => 'none', stroke-width => 2)

# %% [markdown]
# ---
#
# ## Examples

# %% [markdown]
# ### Basic examples

# %% [markdown]
# The first number whose representation takes three summands is 12:

# %%
zeckendorf-representation(12)
# Out:
# [1 0 1 0 1]

# %% [markdown]
# This corresponds to $8 + 3 + 1$:

# %%
[2,4,6]».&fibonacci
# Out:
# [1 3 8]

# %% [markdown]
# <div style="width: 50%; border-top: 1px solid gray; margin: 0 auto;"></div>

# %% [markdown]
# The first number whose representation takes four summands is $33$:

# %%
zeckendorf-representation(33)
# Out:
# [1 0 1 0 1 0 1]

# %%
my @z = zeckendorf-representation(33);
([0, |@z.reverse] >>*<< ((1 ... @z.elems + 1)».&fibonacci)).sum
# Out:
# 33

# %% [markdown]
# ### Neat examples

# %% [markdown]
# There are $F_k$ Zeckendorf representations of length $k$; for example, here are the $13$ representations of length $7$:

# %%
#%html
(21 ... 33)».&zeckendorf-representation
==> to-dataset()
==> { to-html($_, field-names => (^$_.head.elems)».Str) }()
# Out:
# <table border="1"><thead><tr><th>0</th><th>1</th><th>2</th><th>3</th><th>4</th><th>5</th><th>6</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td></tr><tr><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1</td></tr><tr><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td></tr><tr><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td></tr></tbody></table>

# %% [markdown]
# This visualizes the same pattern:

# %%
#% js 
my @mat = to-dataset((21 ... 33)».&zeckendorf-representation).map({ $_{|(^$_.elems)} });
js-d3-matrix-plot(@mat, :200width)

# %% [markdown]
# <div style="width: 50%; border-top: 1px solid gray; margin: 0 auto;"></div>

# %% [markdown]
# Make a plot of circle chords that correspond to pairs of integers that have Fibonacci representations with Hamming distance $1$. The chords in slate blue correspond to pairs differences that are prime numbers.

# %%
my @mat = (1 ... 250)».&zeckendorf-representation;
my $max-digits = @mat.tail.elems;
@mat .= map({ [|(0 xx ($max-digits - $_.elems)), |$_] });
my @edges = (^@mat.elems X ^@mat.elems).map({ $_ => hamming-distance(|@mat[$_]) }).grep({ $_.value == 1 })».key;
@edges .= map({ $_.head.Str => $_.tail.Str });
my $g = Graph.new(@edges, vertex-coordinates => Graph::Cycle.new(@mat.elems).vertex-coordinates);
# Out:
# Graph(vertexes => 250, edges => 780, directed => False)

# %%
#% html
my @highlight = @edges.grep({ is-prime($_.value.Int - $_.key.Int) });
$g.dot(
    highlight => {slateblue => @highlight},
    vertex-shape => 'point', 
    vertex-width => 0, 
    vertex-height => 0, 
    edge-thickness => 0.3, 
    :4size,
    engine => 'neato', 
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (20251213.1925)
#  -->
# <!-- Pages: 1 -->
# <svg width="288pt" height="288pt"
#  viewBox="0.00 0.00 288.00 288.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.8858 1.8858) rotate(0) translate(4 148.71)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-148.71 148.72,-148.71 148.72,4 -4,4"/>
# <!-- 104 -->
# <g id="node1" class="node">
# <title>104</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11.09" cy="-110.17" rx="0.36" ry="0.36"/>
# </g>
# <!-- 138 -->
# <g id="node185" class="node">
# <title>138</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3.61" cy="-50.97" rx="0.36" ry="0.36"/>
# </g>
# <!-- 104&#45;&#45;138 -->
# <g id="edge379" class="edge">
# <title>104&#45;&#45;138</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M11,-109.5C10.23,-103.4 4.41,-57.29 3.68,-51.55"/>
# </g>
# <!-- 105 -->
# <g id="node227" class="node">
# <title>105</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.16" cy="-108.62" rx="0.36" ry="0.36"/>
# </g>
# <!-- 104&#45;&#45;105 -->
# <g id="edge304" class="edge">
# <title>104&#45;&#45;105</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M10.79,-109.68C10.66,-109.45 10.5,-109.18 10.37,-108.98"/>
# </g>
# <!-- 185 -->
# <g id="node2" class="node">
# <title>185</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="66.03" cy="-0.63" rx="0.36" ry="0.36"/>
# </g>
# <!-- 188 -->
# <g id="node16" class="node">
# <title>188</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="71.46" cy="-0.36" rx="0.36" ry="0.36"/>
# </g>
# <!-- 185&#45;&#45;188 -->
# <g id="edge649" class="edge">
# <title>185&#45;&#45;188</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M66.88,-0.59C67.93,-0.54 69.7,-0.45 70.7,-0.4"/>
# </g>
# <!-- 41 -->
# <g id="node38" class="node">
# <title>41</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="110.94" cy="-133.15" rx="0.36" ry="0.36"/>
# </g>
# <!-- 185&#45;&#45;41 -->
# <g id="edge417" class="edge">
# <title>185&#45;&#45;41</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M66.16,-1.01C68.67,-8.42 107.08,-121.74 110.67,-132.35"/>
# </g>
# <!-- 186 -->
# <g id="node177" class="node">
# <title>186</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="67.84" cy="-0.5" rx="0.36" ry="0.36"/>
# </g>
# <!-- 185&#45;&#45;186 -->
# <g id="edge279" class="edge">
# <title>185&#45;&#45;186</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M66.61,-0.59C66.87,-0.57 67.18,-0.55 67.42,-0.53"/>
# </g>
# <!-- 187 -->
# <g id="node184" class="node">
# <title>187</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="69.65" cy="-0.41" rx="0.36" ry="0.36"/>
# </g>
# <!-- 185&#45;&#45;187 -->
# <g id="edge648" class="edge">
# <title>185&#45;&#45;187</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M66.87,-0.58C67.54,-0.54 68.46,-0.48 69.05,-0.44"/>
# </g>
# <!-- 48 -->
# <g id="node3" class="node">
# <title>48</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="99.7" cy="-138.96" rx="0.36" ry="0.36"/>
# </g>
# <!-- 53 -->
# <g id="node115" class="node">
# <title>53</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="91.14" cy="-141.86" rx="0.36" ry="0.36"/>
# </g>
# <!-- 48&#45;&#45;53 -->
# <g id="edge653" class="edge">
# <title>48&#45;&#45;53</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M98.91,-139.23C97.19,-139.81 93.14,-141.19 91.68,-141.68"/>
# </g>
# <!-- 133 -->
# <g id="node4" class="node">
# <title>133</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1.47" cy="-59.75" rx="0.36" ry="0.36"/>
# </g>
# <!-- 134 -->
# <g id="node14" class="node">
# <title>134</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1.81" cy="-57.98" rx="0.36" ry="0.36"/>
# </g>
# <!-- 133&#45;&#45;134 -->
# <g id="edge429" class="edge">
# <title>133&#45;&#45;134</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M1.58,-59.19C1.63,-58.93 1.69,-58.63 1.73,-58.39"/>
# </g>
# <!-- 99 -->
# <g id="node34" class="node">
# <title>99</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="16.31" cy="-117.55" rx="0.36" ry="0.36"/>
# </g>
# <!-- 133&#45;&#45;99 -->
# <g id="edge28" class="edge">
# <title>133&#45;&#45;99</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M1.64,-60.4C3.17,-66.35 14.72,-111.37 16.16,-116.98"/>
# </g>
# <!-- 242 -->
# <g id="node5" class="node">
# <title>242</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="142.53" cy="-56.21" rx="0.36" ry="0.36"/>
# </g>
# <!-- 80 -->
# <g id="node6" class="node">
# <title>80</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="43.35" cy="-138.25" rx="0.36" ry="0.36"/>
# </g>
# <!-- 82 -->
# <g id="node113" class="node">
# <title>82</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="40.08" cy="-136.71" rx="0.36" ry="0.36"/>
# </g>
# <!-- 80&#45;&#45;82 -->
# <g id="edge701" class="edge">
# <title>80&#45;&#45;82</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M42.59,-137.89C41.99,-137.61 41.16,-137.22 40.62,-136.97"/>
# </g>
# <!-- 81 -->
# <g id="node209" class="node">
# <title>81</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="41.7" cy="-137.5" rx="0.36" ry="0.36"/>
# </g>
# <!-- 80&#45;&#45;81 -->
# <g id="edge328" class="edge">
# <title>80&#45;&#45;81</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M42.83,-138.01C42.59,-137.9 42.31,-137.78 42.09,-137.68"/>
# </g>
# <!-- 235 -->
# <g id="node7" class="node">
# <title>235</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="138.62" cy="-44.18" rx="0.36" ry="0.36"/>
# </g>
# <!-- 236 -->
# <g id="node99" class="node">
# <title>236</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="139.3" cy="-45.85" rx="0.36" ry="0.36"/>
# </g>
# <!-- 235&#45;&#45;236 -->
# <g id="edge101" class="edge">
# <title>235&#45;&#45;236</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M138.83,-44.71C138.93,-44.95 139.05,-45.24 139.14,-45.46"/>
# </g>
# <!-- 248 -->
# <g id="node219" class="node">
# <title>248</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="144.16" cy="-66.93" rx="0.36" ry="0.36"/>
# </g>
# <!-- 235&#45;&#45;248 -->
# <g id="edge577" class="edge">
# <title>235&#45;&#45;248</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M138.75,-44.74C139.5,-47.8 143.08,-62.5 143.96,-66.12"/>
# </g>
# <!-- 243 -->
# <g id="node225" class="node">
# <title>243</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="142.91" cy="-57.98" rx="0.36" ry="0.36"/>
# </g>
# <!-- 235&#45;&#45;243 -->
# <g id="edge376" class="edge">
# <title>235&#45;&#45;243</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.3" d="M138.8,-44.77C139.49,-47 141.94,-54.87 142.69,-57.27"/>
# </g>
# <!-- 13 -->
# <g id="node8" class="node">
# <title>13</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="141.11" cy="-93.74" rx="0.36" ry="0.36"/>
# </g>
# <!-- 246 -->
# <g id="node28" class="node">
# <title>246</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="143.79" cy="-63.33" rx="0.36" ry="0.36"/>
# </g>
# <!-- 13&#45;&#45;246 -->
# <g id="edge660" class="edge">
# <title>13&#45;&#45;246</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M141.18,-92.99C141.55,-88.75 143.39,-67.84 143.74,-63.95"/>
# </g>
# <!-- 18 -->
# <g id="node44" class="node">
# <title>18</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="137.89" cy="-102.19" rx="0.36" ry="0.36"/>
# </g>
# <!-- 13&#45;&#45;18 -->
# <g id="edge491" class="edge">
# <title>13&#45;&#45;18</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M140.81,-94.52C140.16,-96.22 138.64,-100.22 138.09,-101.66"/>
# </g>
# <!-- 16 -->
# <g id="node49" class="node">
# <title>16</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="139.3" cy="-98.86" rx="0.36" ry="0.36"/>
# </g>
# <!-- 13&#45;&#45;16 -->
# <g id="edge476" class="edge">
# <title>13&#45;&#45;16</title>
# <path fill="none" stroke="slateblue" stroke-width="0.3" d="M140.83,-94.54C140.48,-95.53 139.89,-97.2 139.56,-98.15"/>
# </g>
# <!-- 47 -->
# <g id="node76" class="node">
# <title>47</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="101.37" cy="-138.25" r
